# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from nltk.tokenize import word_tokenize
import string
import warnings
warnings.filterwarnings('ignore')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from utils import *
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\jorge.grisman\AppData\Roaming\nltk_data...

# %%
###### Read in training data ######

# %%
def read_and_clean_data(file_path):
    """
    This function reads a csv file into a pandas dataframe, drops duplicate rows based on the 'uniqueID' column and resets the index.
    
    Parameters:
    file_path (str): The path to the csv file
    
    Returns:
    df (DataFrame): The cleaned pandas dataframe
    """
    try:
        # Read the csv file
        df = pd.read_csv(file_path)
        
        # Drop duplicates based on 'uniqueID' column
        df.drop_duplicates(subset='uniqueID', keep='first', inplace=True)
        
        # Reset index
        df.reset_index(drop=True, inplace=True)
        
        return df
    
    except FileNotFoundError:
        print(f"The file {file_path} does not exist.")
        return None
    except pd.errors.EmptyDataError:
        print(f"The file {file_path} is empty.")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# Usage
df = read_and_clean_data('drugsComTrain_raw.csv')

# %%
from pandas import option_context

with option_context('display.max_rows', None,'display.max_colwidth', 120,'display.max_columns',120):
              display(df.head(3))
# Out:
#    uniqueID    drugName                     condition  \
# 0    206461   Valsartan  Left Ventricular Dysfunction
# 1     95260  Guanfacine                          ADHD
# 2     92703      Lybrel                 Birth Control
#
#                                                                                                                     review  \
# 0                                          "It has no side effect, I take it in combination of Bystolic 5 Mg and Fish Oil"
# 1  "My son is halfway through his fourth week of Intuniv. We became concerned when he began this last week, when he sta...
# 2  "I used to take another oral contraceptive, which had 21 pill cycle, and was very happy- very light periods, max 5 d...
#
#    rating       date  usefulCount
# 0       9  20-May-12           27
# 1       8  27-Apr-10          192
# 2       5  14-Dec-09           17

# %%
from pandas import option_context

with option_context('display.max_rows', None,'display.max_colwidth', 120,'display.max_columns',120):
              display(df.tail(3))
# Out:
#         uniqueID            drugName              condition  \
# 161294    187382             Orencia   Rheumatoid Arthritis
# 161295     47128  Thyroid desiccated    Underactive Thyroid
# 161296    215220        Lubiprostone  Constipation, Chronic
#
#                                                                                                                          review  \
# 161294                          "Limited improvement after 4 months, developed bad rash and MD refused to continue medication."
# 161295  "I&#039;ve been on thyroid medication 49 years, I spent my first 38 on Synthroid and various t4 formulas, I could no...
# 161296  "I&#039;ve had chronic constipation all my adult life. Tried Linzess, it worked for a month then stopped. Doctor sta...
#
#         rating       date  usefulCount
# 161294       2  15-Mar-14           35
# 161295      10  19-Sep-15           79
# 161296       9  13-Dec-14          116

# %%
#Shape of data
print(f'There are {df.shape[0]} rows and {df.shape[1]} columns in the training dataset')
# Out:
# There are 161297 rows and 7 columns in the training dataset

# %%
###### Null values ######

# %%
def check_null_values(df):
    """
    This function checks for null values in a pandas dataframe and calculates the percentage of null values in the dataset.
    
    Parameters:
    df (DataFrame): The pandas dataframe to check
    
    Returns:
    None
    """
    try:
        # Check for null values
        null_values = df.isna().sum()
        print(f"Null values in each column:\n{null_values}")
        
        # Calculate and print the percentage of null values in the dataset
        null_percentage = round(null_values.sum() / np.product(df.shape) * 100, 1)
        print(f"Null values represent:\n\t{null_percentage}% of the dataset")
        
    except Exception as e:
        print(f"An error occurred: {e}")

#### Usage
check_null_values(df)
# Out:
# Null values in each column:
# uniqueID         0
# drugName         0
# condition      899
# review           0
# rating           0
# date             0
# usefulCount      0
# dtype: int64
# Null values represent:
# 	0.1% of the dataset

# %% [markdown]
# ## Comments:
# * Rows where condition is not present represent < 1% of the total dataset. Let's remove.

# %%
df = df.dropna()

# %%
#Check dtypes of columns
df.dtypes
# Out:
# uniqueID        int64
# drugName       object
# condition      object
# review         object
# rating          int64
# date           object
# usefulCount     int64
# dtype: object

# %% [markdown]
# ## Comments:
# * Everything is text or integer. Looks ok. Except let's convert date to datetime

# %%
#Converting to datetime
df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# # EDA

# %%
###### Total unique drug names ######

# %%
def count_unique_values(df, column):
    """
    This function counts the number of unique values in a specified column of a pandas dataframe.
    
    Parameters:
    df (DataFrame): The pandas dataframe to check
    column (str): The column in which to count unique values
    
    Returns:
    None
    """
    try:
        # Count unique values
        unique_values = df[column].nunique()
        print(f"{unique_values} unique values in {column}")
        
    except KeyError:
        print(f"The column {column} does not exist in the dataframe.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Usage
count_unique_values(df, "drugName")
# Out:
# 3436 unique values in drugName

# %%
###### Average number of reviews for each drug ######

# %%
def average_reviews(df, group_column, count_column):
    """
    This function calculates the average number of reviews for each group in a pandas dataframe.
    
    Parameters:
    df (DataFrame): The pandas dataframe to check
    group_column (str): The column to group by
    count_column (str): The column to count
    
    Returns:
    None
    """
    try:
        # Group by column and count reviews
        tot_dr = pd.DataFrame(df.groupby([group_column])[count_column].count().sort_values(ascending=False)).reset_index()
        tot_dr = tot_dr.rename(columns = {count_column:'Count'})
        
        # Describe the count
        description = tot_dr['Count'].describe()
        print(description)
        
    except KeyError as e:
        print(f"One or more of the columns do not exist in the dataframe: {e}")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
average_reviews(df, "drugName", "uniqueID")
# Out:
# count    3436.000000
# mean       46.943248
# std       164.710284
# min         1.000000
# 25%         2.000000
# 50%         5.000000
# 75%        26.000000
# max      3657.000000
# Name: Count, dtype: float64

# %%
######  plot_reviews ######

# %%
def plot_reviews(df, group_column, count_column):
    """
    This function plots the distribution of the number of reviews for each group in a pandas dataframe.
    
    Parameters:
    df (DataFrame): The pandas dataframe to check
    group_column (str): The column to group by
    count_column (str): The column to count
    
    Returns:
    None
    """
    try:
        # Group by column and count reviews
        tot_dr = pd.DataFrame(df.groupby([group_column])[count_column].count().sort_values(ascending=False)).reset_index()
        tot_dr = tot_dr.rename(columns = {count_column:'Count'})
        
        # Plot the distribution
        plt.figure(figsize=(11,7))
        sns.histplot(tot_dr['Count'], bins=50, kde=True)
        plt.title('Distribution of Number of Reviews per Group')
        plt.xlabel('Number of Reviews')
        plt.ylabel('Frequency')
        plt.show()
        
    except KeyError as e:
        print(f"One or more of the columns do not exist in the dataframe: {e}")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
plot_reviews(df, "drugName", "uniqueID")

# %%
##### Median number of drug reviews for each drug #####

# %%
def median_reviews(df, group_column, count_column):
    """
    This function calculates the median number of reviews for each group in a pandas dataframe.
    
    Parameters:
    df (DataFrame): The pandas dataframe to check
    group_column (str): The column to group by
    count_column (str): The column to count
    
    Returns:
    None
    """
    try:
        # Group by column and count reviews
        med_dr = pd.DataFrame(df.groupby([group_column])[count_column].count()).reset_index()
        
        # Calculate the median
        median = med_dr[count_column].median()
        print(f"The median number of reviews for each {group_column} is {median}")
        
    except KeyError as e:
        print(f"One or more of the columns do not exist in the dataframe: {e}")
    except Exception as e:
        print(f"An error occurred: {e}")

# Usage
median_reviews(df, "drugName", "uniqueID")
# Out:
# The median number of reviews for each drugName is 5.0

# %% [markdown]
# ## Comments:
# * There are on average 46 reviews for each drug. Median is 5. This is probably driven by a few drugs having the large majority of reviews.

# %%
#How many unique drugs had less than 5 reviews?
tot_dr['drugName'][tot_dr['Count'] < 5].nunique()
# Out:
# 1588

# %%
#What percentage of total drugs reviewed was this?
print( f'{round(tot_dr["drugName"][tot_dr["Count"] < 5].nunique()/len(tot_dr) * 100,1)}% of all drugs had less than 5 reviews')
# Out:
# 46.3% of all drugs had less than 5 reviews

# %% [markdown]
# ## Comments:
# * Seems like only a few drugs mights be driving most of the reviews. Let's see the total percentage

# %%
#Look at top 50
top_50 = round(tot_dr.nlargest(n = 50, columns = 'Count').sum()[1]/tot_dr['Count'].sum()*100,1)
print(f'The top 50 drugs with the most reviews make up {top_50}% of the total reviews')
# Out:
# The top 50 drugs with the most reviews make up 32.9% of the total reviews

# %%
#What are the names of these drugs with counts?

tot_dr.head(50)
# Out:
#                                              drugName  Count
# 0                                      Levonorgestrel   3631
# 1                                        Etonogestrel   3321
# 2                   Ethinyl estradiol / norethindrone   2750
# 3                                           Nexplanon   2156
# 4                    Ethinyl estradiol / norgestimate   2033
# 5                  Ethinyl estradiol / levonorgestrel   1809
# 6                                         Phentermine   1538
# 7                                          Sertraline   1353
# 8                                        Escitalopram   1287
# 9                                              Mirena   1242
# 10                                           Implanon   1102
# 11                                         Gabapentin   1042
# 12                                          Bupropion   1017
# 13                                        Venlafaxine   1012
# 14                                         Miconazole    998
# 15                                         Citalopram    994
# 16                                Medroxyprogesterone    971
# 17                                            Lexapro    952
# 18                             Bupropion / naltrexone    945
# 19                                         Duloxetine    931
# 20                                           Contrave    920
# 21                                      Metronidazole    920
# 22                                       Depo-Provera    882
# 23                                           Cymbalta    864
# 24                   Drospirenone / ethinyl estradiol    856
# 25                                              Skyla    824
# 26                                         Clonazepam    824
# 27                                         Quetiapine    823
# 28                                           Tramadol    816
# 29                                             Zoloft    805
# 30                                        Varenicline    787
# 31                                         Fluoxetine    763
# 32                                        Liraglutide    752
# 33                                        Tioconazole    706
# 34                                         Alprazolam    697
# 35                                      Amitriptyline    695
# 36                                     Lo Loestrin Fe    680
# 37                                         Paroxetine    643
# 38                                            Chantix    637
# 39                   Ethinyl estradiol / etonogestrel    635
# 40                                        Doxycycline    627
# 41  Magnesium sulfate / potassium sulfate / sodium...    626
# 42                                           NuvaRing    622
# 43                                         Pregabalin    622
# 44                                             Copper    607
# 45                                             Plan B    606
# 46                                         Topiramate    603
# 47                              Suprep Bowel Prep Kit    598
# 48                                        Lamotrigine    589
# 49                                          Trazodone    584

# %% [markdown]
# ## Comments:
# * Most of these appear to be contraceptives,birth control, etc. Let's look by drug indication. Some of these drugs have more than one indication such as Levonorgestrel

# %%
tot_dr_ind = pd.DataFrame(df.groupby(['condition'])['uniqueID'].count().sort_values(ascending=False)).reset_index()
tot_dr_ind = tot_dr_ind.rename(columns = {'uniqueID':'Count'})

tot_dr_ind['percent_total_reviews']  = round(tot_dr_ind['Count'] / tot_dr_ind['Count'].sum() * 100,1)

# %%
tot_dr_ind.head(21)
# Out:
#                     condition  Count  percent_total_reviews
# 0               Birth Control  28788                   17.9
# 1                  Depression   9069                    5.7
# 2                        Pain   6145                    3.8
# 3                     Anxiety   5904                    3.7
# 4                        Acne   5588                    3.5
# 5             Bipolar Disorde   4224                    2.6
# 6                    Insomnia   3673                    2.3
# 7                 Weight Loss   3609                    2.3
# 8                     Obesity   3568                    2.2
# 9                        ADHD   3383                    2.1
# 10           Diabetes, Type 2   2554                    1.6
# 11    Emergency Contraception   2463                    1.5
# 12        High Blood Pressure   2321                    1.4
# 13    Vaginal Yeast Infection   2274                    1.4
# 14  Abnormal Uterine Bleeding   2096                    1.3
# 15          Bowel Preparation   1859                    1.2
# 16                ibromyalgia   1791                    1.1
# 17          Smoking Cessation   1780                    1.1
# 18                   Migraine   1694                    1.1
# 19         Anxiety and Stress   1663                    1.0
# 20   Major Depressive Disorde   1607                    1.0

# %% [markdown]
# ## Comments:
# * Most of reviews are for birth control and mental health conditions. Let's look at other conditions

# %%
pd.DataFrame(data = list(tot_dr_ind['condition'].unique()), columns=['condition']).sort_values(by='condition',ascending=True).head(80)
# Out:
#                                         condition
# 144    0</span> users found this comment helpful.
# 286   10</span> users found this comment helpful.
# 762  110</span> users found this comment helpful.
# 424   11</span> users found this comment helpful.
# 747  121</span> users found this comment helpful.
# ..                                            ...
# 768                                AV Heart Block
# 686                          Abdominal Distension
# 14                      Abnormal Uterine Bleeding
# 491                                      Abortion
# 782                        Acetaminophen Overdose
#
# [80 rows x 1 columns]

# %% [markdown]
# ## Comments:
# * This is a sorted series of the different conditions each drug treats found during EDA. Looks like some of them have the number of users who found helpful as the drug name. Let's see if we an replace these with condition that drug treats where it is actually listed

# %%
#Make a list of drugs where there were comments helpful marked
com_drugs = list(df['drugName'][df['condition'].str.contains('comment helpful')])

#Put all these drugs into a dataframe
com_drugs_df = df[['drugName','condition']][df['drugName'].isin(com_drugs)]

#See count of unique conditions each drug treats
com_drugs_df_c = pd.DataFrame(com_drugs_df.groupby('drugName')['condition'].nunique()).reset_index()

com_drugs_df_c[com_drugs_df_c['condition'] == 1]
# Out:
#                                 drugName  condition
# 7                              Aerobid-M          1
# 8    Alavert D-12 Hour Allergy and Sinus          1
# 67                              Dantrium          1
# 109                   Fleet Phospho Soda          1
# 113                            Fluoridex          1
# 115                              Fragmin          1
# 123    Hair Regrowth Treatment for Women          1
# 144                               Lescol          1
# 160    Lotrimin AF Athlete's Foot Powder          1
# 167                              Maxidex          1
# 191                               Nor-QD          1
# 196                             Nutropin          1
# 199                               Nystop          1
# 204                              Orapred          1
# 239                              Regimex          1
# 253         Rogaine Men's Extra Strength          1
# 268                           Spectracef          1
# 284                            Taztia XT          1
# 306                      Uroqid-Acid No2          1

# %%
drugs_one_cond = list(com_drugs_df_c['drugName'][com_drugs_df_c['condition'] == 1].unique())

df[df['drugName'].isin(drugs_one_cond)].sort_values(by='drugName',ascending=True)
# Out:
#         uniqueID                             drugName  \
# 31706     131185                            Aerobid-M
# 678        80302  Alavert D-12 Hour Allergy and Sinus
# 75127     204288                             Dantrium
# 117087     69138                   Fleet Phospho Soda
# 152441      8055                            Fluoridex
# 96406      32784                              Fragmin
# 92511      20813    Hair Regrowth Treatment for Women
# 50221     195158                               Lescol
# 107948     36113    Lotrimin AF Athlete's Foot Powder
# 38284      14325                              Maxidex
# 2203      160076                               Nor-QD
# 62623     127214                             Nutropin
# 133751     58553                               Nystop
# 109247     51808                              Orapred
# 145653    198569                              Regimex
# 62255      23755         Rogaine Men's Extra Strength
# 56591      53244                           Spectracef
# 26151     153588                            Taztia XT
# 57073     223595                      Uroqid-Acid No2
#
#                                           condition  \
# 31706    1</span> users found this comment helpful.
# 678      1</span> users found this comment helpful.
# 75127   98</span> users found this comment helpful.
# 117087   6</span> users found this comment helpful.
# 152441   6</span> users found this comment helpful.
# 96406    4</span> users found this comment helpful.
# 92511   14</span> users found this comment helpful.
# 50221   25</span> users found this comment helpful.
# 107948   1</span> users found this comment helpful.
# 38284    4</span> users found this comment helpful.
# 2203     6</span> users found this comment helpful.
# 62623   18</span> users found this comment helpful.
# 133751   1</span> users found this comment helpful.
# 109247  12</span> users found this comment helpful.
# 145653   6</span> users found this comment helpful.
# 62255   31</span> users found this comment helpful.
# 56591    4</span> users found this comment helpful.
# 26151   18</span> users found this comment helpful.
# 57073    6</span> users found this comment helpful.
#
#                                                    review  rating       date  \
# 31706   "Fantastic, the mentholated one is great &amp;...      10 2014-09-28
# 678     "I&#039;ve found this product helps to shrink ...       5 2016-04-15
# 75127   "I was hit by an uninsured drunk driver in &#0...      10 2008-12-25
# 117087  "This site provided information not on the bot...       6 2008-09-07
# 152441  "My dentist suggested using it regularly after...      10 2013-03-14
# 96406              "Information was clear to understand."      10 2008-05-14
# 92511   "W/in 2 hours of application I was cramping. P...       1 2016-11-21
# 50221   "Lescol lowered my LDL cholesterol from 270 to...       9 2008-08-31
# 107948  "Product works but the dispenser is terrible. ...       9 2010-07-16
# 38284   "I was in coma for 3 weeks. When i eventually ...       6 2016-10-15
# 2203    "Well my experience with this is ok it was goo...       4 2012-07-07
# 62623   "My son had a tumor removed from the pituitary...      10 2009-03-26
# 133751  "After less than a week&#039;s use I developed...       1 2017-07-27
# 109247  "My toddler son uses this to help with his ast...       7 2008-03-17
# 145653  "Regimex did curve my appetite but it also mad...       7 2013-10-06
# 62255   "After three days use I started having large r...       1 2011-10-14
# 56591   "I had a sinus infection. I had never had any ...       1 2009-07-24
# 26151   "Great medicine. Helped me revert to normal rh...       9 2012-12-23
# 57073   "It has been the only thing that has worked fo...      10 2012-07-12
#
#         usefulCount
# 31706             1
# 678               1
# 75127            98
# 117087            6
# 152441            6
# 96406             4
# 92511            14
# 50221            25
# 107948            1
# 38284             4
# 2203              6
# 62623            18
# 133751            1
# 109247           12
# 145653            6
# 62255            31
# 56591             4
# 26151            18
# 57073             6

# %% [markdown]
# ## Comments:
# * The drugs that only treated one condition with "comment helpful" for the conditions were few as you can see above. All the other drugs that had a this as the condition had multiple conditions it could treat. Therefore, it would be hard to know the condition it was prescribed for for these to fill them in. Going to drop these rows

# %%
df = df[~df['condition'].str.contains('comment helpful')]

# %%
#Which drug class had the highest rating with at least 50 reviews?
cond_mean_ct = df.groupby('condition')['rating'].agg(['mean','count']).reset_index()
cond_mean_ct = cond_mean_ct[cond_mean_ct['count'] > 50]
cond_mean_ct.nlargest(columns = 'mean', n=20)
# Out:
#                                    condition      mean  count
# 791                            mance Anxiety  9.673797    187
# 20                        Alcohol Withdrawal  9.244240    217
# 191                               Dermatitis  9.096774     93
# 150                               Cold Sores  9.068120    367
# 328                            Hyperhidrosis  8.935007    677
# 19                        Alcohol Dependence  8.894330    388
# 82                       Barrett's Esophagus  8.864865     74
# 242                      Erosive Esophagitis  8.842857     70
# 308              Herpes Simplex, Suppression  8.789157    166
# 146                        Cluster Headaches  8.771084    166
# 670                        Smoking Cessation  8.758427   1780
# 422                                  Melasma  8.750000     72
# 288                                 Headache  8.746300    473
# 658                           Sinus Symptoms  8.732558     86
# 47                                  Anorexia  8.712500     80
# 508  Organ Transplant, Rejection Prophylaxis  8.660377     53
# 463    Nausea/Vomiting, Chemotherapy Induced  8.658228     79
# 501                        Opiate Dependence  8.633920   1079
# 227                                   Eczema  8.620482    166
# 282                            HIV Infection  8.578862    615

# %%
#Which drug class had the lowest rating with at least 50 reviews?
cond_mean_ct = df.groupby('condition')['rating'].agg(['mean','count']).reset_index()
cond_mean_ct = cond_mean_ct[cond_mean_ct['count'] > 50]
cond_mean_ct.nsmallest(columns = 'mean', n=20)
# Out:
#                       condition      mean  count
# 751     Vaginal Yeast Infection  4.082234   2274
# 4     Abnormal Uterine Bleeding  4.372615   2096
# 597                 Prostatitis  4.560440     91
# 513                Osteoporosis  4.833333    372
# 161  Constipation, Drug Induced  5.083333    228
# 93            Bladder Infection  5.144304    395
# 215             Dry Eye Disease  5.149660    147
# 745     Urinary Tract Infection  5.335866   1316
# 385  Keratoconjunctivitis Sicca  5.425926     54
# 62                Asthma, acute  5.444444    135
# 27          Alzheimer's Disease  5.494118     85
# 387           Kidney Infections  5.581197    117
# 103                Breast Cance  5.676471    272
# 69           Atrophic Vaginitis  5.725275    182
# 314            High Cholesterol  5.733224    611
# 515                Otitis Media  5.802632    152
# 659                   Sinusitis  5.834731    835
# 80     Bacterial Skin Infection  5.835616    146
# 429         Menstrual Disorders  5.845714    350
# 518           Overactive Bladde  5.871157    683

# %% [markdown]
# ## Comments:
# * There are many different drugs and conditions in this dataset. For purposes of this project, I am only interested in drugs that treat mental health conditions. Going to remove anything not related to this

# %% [markdown]
# ## Search for drugs that treat mental health conditions in the dataset

# %%
#I found an html table at https://denalirx.com/top-200-drugs-list that lists the drug class for the top 200 drugs(assuming prescribed?)drugs. We can add the drug class to our dataset for the drugs
#that are found. This will make it easier to look for conditions related to mental health

df_dc = pd.read_html(io = 'https://denalirx.com/top-200-drugs-list')[0]

#Rename column names since they imported with special characters
mapping = {df_dc.columns[0]:'Generic Name', df_dc.columns[1]: 'Brand Name'}
df_dc = df_dc.rename(columns=mapping)

#See the new dataframe with the drug name and classes
df_dc
# Out:
#                         Generic Name Brand Name            Drug Class  \
# 0                      Levothyroxine  Synthroid   Hormone replacement
# 1                   Hydrocodone/APAP    Vicodin             Analgesic
# 2                        Amoxicillin     Amoxil            Antibiotic
# 3                         Lisinopril   Prinivil      Antihypertensive
# 4                       Esomeprazole     Nexium         Antacid (PPI)
# ..                               ...        ...                   ...
# 195                       Lomitapide   Juxtapid  Cholesterol lowering
# 196                       Tizanidine   Zanaflex        Muscle Relaxer
# 197  Amphetamine / Dextroamphetamine   Adderall                  ADHD
# 198                   Zoster Vaccine   Zostavax      Shingles Vaccine
# 199            Ezetimibe Simvastatin    Vytorin  Cholesterol lowering
#
#     DEA Schedule
# 0              -
# 1           C-II
# 2              -
# 3              -
# 4              -
# ..           ...
# 195            -
# 196            -
# 197         C-II
# 198            -
# 199            -
#
# [200 rows x 4 columns]

# %%
#Merge this with the original dataframe on both brand name and generic name to get the drug class
df = pd.merge(df,df_dc[['Brand Name','Drug Class']],left_on='drugName',right_on='Brand Name',how='left')
df = pd.merge(df,df_dc[['Generic Name','Drug Class']],left_on='drugName',right_on='Generic Name',how='left')

#Fill drug class with drug class from generic name for the drug
df['Drug Class_x'] = np.where( (df['Drug Class_x'].isna()==True) & (df['Drug Class_y'].isna()==False), df['Drug Class_y'], np.nan)

#Rename Drug Class_x as Drug Class
df = df.rename(columns = {'Drug Class_x':'Drug Class'})

#Drop other columns you do not need
df = df.drop(columns = 'Drug Class_y')

df
# Out:
#         uniqueID                  drugName                     condition  \
# 0         206461                 Valsartan  Left Ventricular Dysfunction
# 1          95260                Guanfacine                          ADHD
# 2          92703                    Lybrel                 Birth Control
# 3         138000                Ortho Evra                 Birth Control
# 4          35696  Buprenorphine / naloxone             Opiate Dependence
# ...          ...                       ...                           ...
# 159493    191035                   Campral            Alcohol Dependence
# 159494    127085            Metoclopramide               Nausea/Vomiting
# 159495    187382                   Orencia          Rheumatoid Arthritis
# 159496     47128        Thyroid desiccated           Underactive Thyroid
# 159497    215220              Lubiprostone         Constipation, Chronic
#
#                                                    review  rating       date  \
# 0       "It has no side effect, I take it in combinati...       9 2012-05-20
# 1       "My son is halfway through his fourth week of ...       8 2010-04-27
# 2       "I used to take another oral contraceptive, wh...       5 2009-12-14
# 3       "This is my first time using any form of birth...       8 2015-11-03
# 4       "Suboxone has completely turned my life around...       9 2016-11-27
# ...                                                   ...     ...        ...
# 159493  "I wrote my first report in Mid-October of 201...      10 2015-05-31
# 159494  "I was given this in IV before surgey. I immed...       1 2011-11-01
# 159495  "Limited improvement after 4 months, developed...       2 2014-03-15
# 159496  "I&#039;ve been on thyroid medication 49 years...      10 2015-09-19
# 159497  "I&#039;ve had chronic constipation all my adu...       9 2014-12-13
#
#         usefulCount Brand Name        Drug Class    Generic Name
# 0                27        NaN  Antihypertensive       Valsartan
# 1               192        NaN               NaN             NaN
# 2                17        NaN               NaN             NaN
# 3                10        NaN               NaN             NaN
# 4                37        NaN               NaN             NaN
# ...             ...        ...               ...             ...
# 159493          125        NaN               NaN             NaN
# 159494           34        NaN     Antispasmodic  Metoclopramide
# 159495           35        NaN               NaN             NaN
# 159496           79        NaN               NaN             NaN
# 159497          116        NaN               NaN             NaN
#
# [159498 rows x 10 columns]

# %%
#See a list of all the unique drug classes
list(df['Drug Class'].unique())
# Out:
# ['Antihypertensive',
#  nan,
#  'Antipsychotic',
#  'Anticonvulsant',
#  'Antidiabetic',
#  'Antidepressant',
#  'Antiepileptic',
#  'Anti-arthritic',
#  'Antibiotic',
#  'Antifungal',
#  'Antianxiety',
#  'Urinary retention',
#  'Erectile dysfunction',
#  'Analgesic',
#  'Diuretic',
#  "Anti-Parkinson's",
#  'Analgesic (NSAID)',
#  'Antitussive (cough suppressant)',
#  'Cholesterol lowering',
#  'Hormone replacement',
#  'ADHD',
#  'Muscle Relaxer',
#  'Opioid addiction',
#  'Anti-asthmatic',
#  'Antacid (PPI)',
#  'Antiviral',
#  'Antispasmodic',
#  'Antiemetic',
#  'Sleep aid',
#  'Anti-smoking',
#  'Incontinence',
#  'Antimigraine',
#  'Appetite suppressant',
#  'Antihistamine',
#  'Antirheumatic',
#  'Antigout',
#  'Antacid (H2)',
#  'Anti-inflammatory steriod',
#  'Analgesic (urinary)',
#  'C.O.P.D.',
#  'Sleep Aid',
#  'Immunosuppressant',
#  'Anticoagulant',
#  'Osteoporosis',
#  'Bladder relaxant',
#  'Urinary retention / Antihypertensive',
#  'Antidementia',
#  'Congestive Heart Failure',
#  'Antiglaucoma',
#  'Anti-inflammatory']

# %% [markdown]
# ## Comments:
#  * Going to focus on only these drug classes for mental health for this project going forward. Antipsychotic, Antidepressant, Antianxiety, ADHD, Opioid addiction, Antidementia

# %%
#Get a new dataframe to only focus on drug classes interested in

df = df[ df['Drug Class'].isin(['Antidepressant','Antipsychotic','Antianxiety','ADHD','Opioid addiction','Antidementia'])]

# %% [markdown]
# # Mental Health Drugs EDA

# %% [markdown]
# * Often times there are certain words that are capitalized in the reviews. Interested in exploring how number of capitalized words could influence the
#   useful counts

# %%
#Classify ratings into negative, neutral or positive

df['rating_class'] = np.where(df['rating'] <= 3, 'Negative',np.nan)
df['rating_class'] = np.where((df['rating'] > 3) & (df['rating'] <=7), 'Neutral',df['rating_class']) 
df['rating_class'] = np.where(df['rating'] > 7, 'Positive',df['rating_class'])

# %%
#Look at average ratings over the years

#Convert date to yyyy/qr
df['date_yq'] = df['date'].dt.year.astype(str) + 'Q' + df['date'].dt.quarter.astype(str)
df['date_yr'] = df['date'].dt.year

plt.figure(figsize=(16,8))
plt.title('Mental Health Drug Class Ratings By Year')
sns.lineplot(data=df, x = 'date_yr', y = 'rating', hue = 'Drug Class',ci=None)
plt.ylabel('Avg. Rating')
plt.yticks(np.arange(0,10,1))
plt.xlabel('Year');

# %% [markdown]
# ## Comments:
#  * Consistent drop of average rating of mental heath drug classes except Opioids over last 10 years, especially Antidementia drugs. Let's explore Antidementia drugs
#     closer

# %%
antidem = df[df['Drug Class'] ==  'Antidementia']

antidem.groupby(['drugName','date_yr'])['rating'].agg(['mean','count'])
# Out:
#                            mean  count
# drugName     date_yr
# Memantine    2011      5.000000      1
#              2013      5.000000      2
#              2014      5.000000      3
#              2015      9.000000      2
#              2016      4.333333      3
#              2017      3.500000      4
# Rivastigmine 2008      9.000000      1
#              2009      8.000000      1
#              2010      9.000000      1
#              2011     10.000000      1
#              2012      7.000000      1
#              2014      8.000000      1
#              2015      7.333333      3
#              2016      1.000000      1
#              2017      1.000000      1

# %% [markdown]
# ## Comments:
#
# * Small number of reviews for antidementia drugs. High variability because of this.

# %% [markdown]
# ### Let's look at drugs in the antidepressant class as these have the most reviews and have seen a decline in avg. reviews since 2014

# %%
df.groupby('Drug Class')['uniqueID'].count().sort_values(ascending=False)
# Out:
# Drug Class
# Antidepressant      10100
# Antianxiety          2737
# Antipsychotic        2182
# ADHD                 1217
# Opioid addiction      327
# Antidementia           26
# Name: uniqueID, dtype: int64

# %%
#Make dataframe just for antidepressants
antidep = df[['drugName','condition','rating','rating_class','date','date_yr']][df['Drug Class'] ==  'Antidepressant']

#Make dummies column for positive, negative and neutral reviews
antidep = pd.concat([antidep.drop('rating_class', axis=1), pd.get_dummies(antidep['rating_class'])], axis=1)

antidep_pos = pd.DataFrame(antidep.groupby('date_yr')['Positive'].sum()/antidep.groupby('date_yr')['Positive'].count()).reset_index()
antidep_neu = pd.DataFrame(antidep.groupby('date_yr')['Neutral'].sum()/antidep.groupby('date_yr')['Neutral'].count()).reset_index()
antidep_neg = pd.DataFrame(antidep.groupby('date_yr')['Negative'].sum()/antidep.groupby('date_yr')['Negative'].count()).reset_index()

antidep_final = antidep_pos.merge(antidep_neu,on='date_yr').merge(antidep_neg,on='date_yr')


ax = antidep_final.set_index('date_yr').plot.bar(stacked = True, title='Antidepressant Reviews by Year',  figsize=(10,6), rot=20, ylabel = 'Percentage of Scores', color=['green','yellow','red'])



# Add this loop to add the annotations
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    
    ax.annotate(f'{height:.0%}', (x + width/2, y + height*.2), ha='center')

# %%
#Antidepressant reviews by year

antidep.groupby('date_yr')['drugName'].count()
# Out:
# date_yr
# 2008     312
# 2009     778
# 2010     566
# 2011     758
# 2012     687
# 2013     911
# 2014     867
# 2015    1656
# 2016    2037
# 2017    1528
# Name: drugName, dtype: int64

# %% [markdown]
# ## Comments:
#
# * Big percentage increase in negative reviews starting in 2015 with a large increase in reviews also. Let's see if that is consistent with other drug classes

# %%
def drug_class_review(drugclass):
    
    #Make dataframe just for antidepressants
    d_class = df[['drugName','condition','rating','rating_class','date','date_yr']][df['Drug Class'] == str(drugclass)]

    #Make dummies column for positive, negative and neutral reviews
    d_class = pd.concat([d_class.drop('rating_class', axis=1), pd.get_dummies(d_class['rating_class'])], axis=1)

    d_class_pos = pd.DataFrame(d_class.groupby('date_yr')['Positive'].sum()/d_class.groupby('date_yr')['Positive'].count()).reset_index()
    d_class_neu = pd.DataFrame(d_class.groupby('date_yr')['Neutral'].sum()/d_class.groupby('date_yr')['Neutral'].count()).reset_index()
    d_class_neg = pd.DataFrame(d_class.groupby('date_yr')['Negative'].sum()/d_class.groupby('date_yr')['Negative'].count()).reset_index()

    d_class_final = d_class_pos.merge(d_class_neu,on='date_yr').merge(d_class_neg,on='date_yr')


    ax = d_class_final.set_index('date_yr').plot.bar(stacked = True, title= f'{drugclass} Reviews by Year',  figsize=(10,6), rot=20, ylabel = 'Percentage of Scores', color=['green','yellow','red'])


    # Add this loop to add the annotations
    for p in ax.patches:
        width = p.get_width()
        height = p.get_height()
        x, y = p.get_xy() 
    
        ax.annotate(f'{height:.0%}', (x + width/2, y + height*.2), ha='center')
    
    return ax

# %%
drug_class_review('Antipsychotic')
drug_class_review('Antianxiety')
drug_class_review('ADHD')
drug_class_review('Opioid addiction')
# Out:
# <AxesSubplot:title={'center':'Opioid addiction Reviews by Year'}, xlabel='date_yr', ylabel='Percentage of Scores'>

# %% [markdown]
# ## Comments:
#
# * Same trend for other mental health drug classes also except for opioids

# %%
#import yake

#doc = df.iloc[[1]]
#doc = str(test['review'])
#full_text = "I've been taking amitriptyline since January 2013 after being diagnosed with fibromyalgia. I tried cymbalta for a week and my Dr decided that since it kept me awake 24/7 that it wasn&#039;t a good fit for me even though it relieved my pain. I started with 25 mg. After 2 weeks I had some breakthrough pain, so my Dr increased my dosage to 50mg and I&#039;m still on that dosage today. For the first full year I was on this I never had pain and felt &#039;cured&#039;. As time went on, it seems to help control my pain. I do still have pain, but at a low manageable level. I take this around 7pm each evening to avoid feeling overly drowsy in the mornings. This med allows me to have a fairly normal life."

#kw_extractor = yake.KeywordExtractor(top=1, stopwords=None)
#keywords = kw_extractor.extract_keywords(full_text)
#for kw, v in keywords:
  #print("Keyphrase: ",kw, ": score", v)


#pd.set_option("display.max_colwidth", -1)
# Out:
# Keyphrase:  amitriptyline since January : score 0.0108087725345513

# %%
#Make columns for cleaned text, length of review, uppercase words and counts and positive or negative sentiment of word using imported utility file

#clean_text(df)
#df['review_length'] = df['review'].apply(text_length)
#df['uppercase_words'] = df['review_clean'].apply(uppercase)
#df['uppercase_count'] = df['uppercase_words'].apply(uppercase_count)
#df['uppercase_positive'] = df['uppercase'].apply(PosSentimentAnalyzer)
#df['uppercase_positive_count'] = df['uppercase'].apply(PosSentimentAnalyzerCount)
#df['uppercase_negative'] = df['uppercase'].apply(NegSentimentAnalyzer)
#df['uppercase_negative_count'] = df['uppercase'].apply(NegSentimentAnalyzerCount)
